# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/kaggle/input/data-cleaning/Airbnb_Open_Data.csv")
# Out:
# /tmp/ipykernel_17/2765098925.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/kaggle/input/data-cleaning/Airbnb_Open_Data.csv")

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...

# %%
df_clean=df.copy()

# %%
df_clean.head(1)
# Out:
#         id                                NAME      host id  \
# 0  1001254  Clean & quiet apt home by the park  80014485718
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
#
# [1 rows x 26 columns]

# %% [markdown]
#  **Deleting redundantt columns**
# * Renaming the columns
# * Dropping duplicates
# * Cleaning indivitual
# * Remove the NAN values from the dataset
# * check for some more Transfomations

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
df_clean.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
column_to_Keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
column_to_drop = ['id','reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
len(column_to_Keep)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(column_to_Keep)
#
# NameError: name 'column_to_Keep' is not defined

# %%
len(column_to_drop)
# Out:
# 7

# %% [markdown]
# # 1st Method  filtering method

# %%
df_clean[column_to_Keep]
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df_clean.shape
# Out:
# (102599, 26)

# %% [markdown]
# # 2nd Method Dropping Cloumn

# %%
df_clean.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df_clean.drop(columns = ["license"])
# Out:
#              id                                              NAME  \
# 0       1001254                Clean & quiet apt home by the park
# 1       1002102                             Skylit Midtown Castle
# 2       1002403               THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                               NaN
# 4       1003689  Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                               ...
# 102594  6092437                        Spare room in Williamsburg
# 102595  6092990                     Best Location near Columbia U
# 102596  6093542                    Comfy, bright room in Brooklyn
# 102597  6094094                  Big Studio-One Stop from Midtown
# 102598  6094647                              585 sf Luxury Studio
#
#             host id host_identity_verified    host name neighbourhood group  \
# 0       80014485718            unconfirmed     Madaline            Brooklyn
# ...

# %%
df_clean.drop(columns = column_to_drop, inplace = True )

# %%
df_clean.shape
# Out:
# (102599, 19)

# %% [markdown]
# # Renaming  the columns

# %%
# correct the column
df_clean.rename(columns = {"NAME": "Name"}, inplace= True)

# %%
df_clean.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country country code instant_bookable  \
# 0  40.64749 -73.97237  United States           US            False
# ...

# %%
df_clean.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
# modefy the all column name
#for i in df_clean.columns:
#    print(i.upper())

new_columns_names  =[]
for i in df_clean.columns:
    new_columns_names.append(i.upper())

# %%
new_columns_names
# Out:
# ['NAME',
#  'HOST ID',
#  'HOST_IDENTITY_VERIFIED',
#  'HOST NAME',
#  'NEIGHBOURHOOD GROUP',
#  'NEIGHBOURHOOD',
#  'LAT',
#  'LONG',
#  'COUNTRY',
#  'COUNTRY CODE',
#  'INSTANT_BOOKABLE',
#  'CANCELLATION_POLICY',
#  'ROOM TYPE',
#  'CONSTRUCTION YEAR',
#  'PRICE',
#  'SERVICE FEE',
#  'MINIMUM NIGHTS',
#  'NUMBER OF REVIEWS',
#  'LAST REVIEW']

# %%
new_dataframe_to_modify = df_clean.copy()

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['Name', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
type(new_columns_names)
# Out:
# list

# %%
new_dataframe_to_modify.columns = new_columns_names

# %%
new_dataframe_to_modify.head()
# Out:
#                                                NAME      HOST ID  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 2               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                               NaN  85098326012
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   HOST_IDENTITY_VERIFIED HOST NAME NEIGHBOURHOOD GROUP NEIGHBOURHOOD  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         LAT      LONG        COUNTRY COUNTRY CODE INSTANT_BOOKABLE  \
# 0  40.64749 -73.97237  United States           US            False
# ...

# %%
new_dataframe_to_modify.columns
# Out:
# Index(['NAME', 'HOST ID', 'HOST_IDENTITY_VERIFIED', 'HOST NAME',
#        'NEIGHBOURHOOD GROUP', 'NEIGHBOURHOOD', 'LAT', 'LONG', 'COUNTRY',
#        'COUNTRY CODE', 'INSTANT_BOOKABLE', 'CANCELLATION_POLICY', 'ROOM TYPE',
#        'CONSTRUCTION YEAR', 'PRICE', 'SERVICE FEE', 'MINIMUM NIGHTS',
#        'NUMBER OF REVIEWS', 'LAST REVIEW'],
#       dtype='object')

# %% [markdown]
# # Deleting redundant columns
# ## Dropping duplicate

# %%
df_clean.duplicated()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_clean.duplicated()
#
# NameError: name 'df_clean' is not defined

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(541)

# %%
df_clean.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df_clean.duplicated().tail()
# Out:
# 102594    True
# 102595    True
# 102596    True
# 102597    True
# 102598    True
# dtype: bool

# %%
df_clean.duplicated().value_counts()
# Out:
# False    102058
# True        541
# Name: count, dtype: int64

# %%
# df_clean.drop_duplicates()
df_clean.drop_duplicates(inplace = True)

df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_clean.isna().sum() # last review has more nan value so drop this column
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %% [markdown]
# # Cl

# %%
df_clean.drop(columns = ["last review"], inplace = True)

# %%
df_clean.isna().sum()
# Out:
# Name                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# Construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %%
df_clean.dropna(inplace = True)

# %%
df_clean.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %% [markdown]
# # Cleaning Indivitual column

# %%
df_clean["host_identity_verified"].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 99342, dtype: object

# %%
df_clean.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn          Kensington
# 1               verified     Jenna           Manhattan             Midtown
# 4               verified    Lyndon           Manhattan         East Harlem
# 5               verified  Michelle           Manhattan         Murray Hill
# 7            unconfirmed      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country code instant_bookable  \
# ...

# %%
df_clean['host_identity_verified']= df_clean["host_identity_verified"].str.upper()

# %%
df_clean.head()
# Out:
#                                                Name      host id  \
# 0                Clean & quiet apt home by the park  80014485718
# 1                             Skylit Midtown Castle  52335172823
# 4  Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5         Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                   BlissArtsSpace!  90821839709
#
#   host_identity_verified host name neighbourhood group       neighbourhood  \
# 0            UNCONFIRMED  Madaline            Brooklyn          Kensington
# 1               VERIFIED     Jenna           Manhattan             Midtown
# 4               VERIFIED    Lyndon           Manhattan         East Harlem
# 5               VERIFIED  Michelle           Manhattan         Murray Hill
# 7            UNCONFIRMED      Emma            Brooklyn  Bedford-Stuyvesant
#
#         lat      long        country country code instant_bookable  \
# ...

# %%
# instant bookable  have string data for converting this numeric
df_clean["instant_bookable"].apply(lambda x:1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: instant_bookable, Length: 99342, dtype: int64

# %%
df_clean["instant_bookable"] = df_clean['instant_bookable'].apply(lambda x:1 if x==True else 0    )

# %%
type(df_clean["instant_bookable"][15])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 15
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17/2002968038.py in <cell line: 0>()
# ----> 1 type(df_clean["instant_bookable"][15])
#
# ...

# %%
#df_clean.reset_index(inplace = True)
df_clean

# %%
df_clean.reset_index()
